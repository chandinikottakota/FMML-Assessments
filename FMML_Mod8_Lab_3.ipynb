# %% [markdown]
# <a href="https://colab.research.google.com/github/chandinikottakota/Module-2-Labs/blob/main/FMML_Mod8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-17 05:02:51--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   124MB/s    in 0.6s
#
# 2023-05-17 05:02:52 (124 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3984 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 608    1603.08148v3  The problem of rare and unknown words is an im...    cs
# 40093  1710.08343v1  Computational ghost imaging (CGI) is a single-...    cs
# 34173  1612.03231v1  With the ever-increasing scientific literature...    cs
# 21656   1304.5417v1  The scaled complex Wishart distribution is a w...  stat
# 36869  1507.05956v6  This paper describes the IBM 704 architecture ...    cs
# ...             ...                                                ...   ...
# 12622  1803.06969v1  We analyze numerically the training dynamics o...  stat
# 35851   1301.6479v2  Ontology-based data access is concerned with q...    cs
# 30669  1712.10042v1  Domain adaptation (DA) aims to generalize a le...    cs
# 31585  1803.07218v1  We propose the first deep learning solution to...    cs
# 38026  cs/0607062v3  We investigate whether one can determine from ...    cs
#
#                                                    title  year  \
# 608                           Pointing the Unknown Words  2016
# 40093    Computational ghost imaging using deep learning  2017
# 34173  A natural language interface to a graph-based ...  2016
# 21656  Analytic Expressions for Stochastic Distances ...  2013
# 36869  Towards a Better Understanding of CAR, CDR, CA...  2015
# ...                                                  ...   ...
# 12622  Comparing Dynamics: Deep Neural Networks versu...  2018
# 35851  Ontology-based Data Access: A Study through Di...  2013
# 30669  Discriminative and Geometry Aware Unsupervised...  2017
# 31585  A Temporally-Aware Interpolation Network for V...  2018
# 38026  Get out the vote: Determining support or oppos...  2006
#
#                                                 keywords
# 608    [important, potentially, influence, performanc...
# 40093  [computational, technique, correlation, intens...
# 34173  [increasing, scientific, literature, interface...
# 21656  [distribution, multilook, polarimetric, litera...
# 36869  [describes, architecture, themselves, compound...
# ...                                                  ...
# 12622  [numerically, developed, statistical, complexi...
# 35851  [concerned, incomplete, knowledge, conjunctive...
# 30669  [adaptation, generalize, distributions, theore...
# 31585  [inpainting, challenging, inpainting, applicat...
# 38026  [investigate, determine, transcripts, congress...
#
# [5187 rows x 6 columns]

# %%
df['keywords']
# Out:
# 608      [important, potentially, influence, performanc...
# 40093    [computational, technique, correlation, intens...
# 34173    [increasing, scientific, literature, interface...
# 21656    [distribution, multilook, polarimetric, litera...
# 36869    [describes, architecture, themselves, compound...
#                                ...
# 25997    [probabilistic, principal, component, insuffic...
# 17854    [identification, combining, character, automat...
# 36056    [programming, prototyping, programming, algori...
# 32366    [efficient, algorithm, computing, euclidean, p...
# 16551    [increasing, recurrent, augmenting, resulting,...
# Name: keywords, Length: 6484, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 9179 words.
# Out of those 4709 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="311e7e46-4222-4338-9d86-357ee46cbacb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("311e7e46-4222-4338-9d86-357ee46cbacb")) {                    Plotly.newPlot(                        "311e7e46-4222-4338-9d86-357ee46cbacb",                        [{"x":["influence","improvements","potentially","important","translation","conditional","traditional","conditioned","adaptively","psychological","performance","naturally","summarization","attention","environment","vocabulary","including","contaminated","reconstructed","detectors","dimensional","technique","correlation","reconstruction","transmitted","computational","intensity","automatically","framework","represents","tokenization","integrates","retrieval","contributions","presented","knowledge","information","techniques","literature","customized","effectively","interface","scientific","processing","bibliographic","complexities","increasing","addresses","recognition","developed","applicable","syntactic","analyzing","interpreting","experimental","designing","practical","linguistic","correctly","statistics","homogeneity","stochastic","inequalities","segmentation","expressions","discrimination","criterion","applications","dissimilarity","experiments","distribution","outperforms","identification","illustrate","expressiveness","distances","comparison","distributions","classification","parameters","suggesting","statistic","capabilities","performed","asymptotic","particular","sensitivity","bhattacharyya","variation","understanding","describes","architecture","themselves","compounding","application","insufficient","interacting","utterances","predicting","generating","uncertainty","initially","underlying","algorithm","collected","combining","informative","incorporate","challenges","complicated","telephone","compensate","unlabeled","extension","selection","facilitate","collaborative","activation","inception","competitive","competition","convolutional","adaptation","dimensionality","concatenation","comparable","represented","objectives","following","formation","introduce","benchmark","convolution","difference","components","empirically","functions","efficiency","convergence","individual","possibilities","outperform","sacrificing","potential","reinforcement","combination","ensembles","mechanism","guarantees","algorithms","crowdsourced","reliability","collective","determined","unsupervised","weighting","crowdsourcing","supervised","performing","otherwise","attending","approaches","exercises","supported","challenge","nintendos","principles","progressive","platforms","experience","parkinsons","gradually","technology","motivation","amalgamation","increases","rehabilitation","dopaminergic","suitability","opportunities","repeatability","prescribed","eventually","precision","complexity","recommend","movements","predictability","character","recursively","regression","interpretable","observations","demonstrate","reformulating","personalization","achieving","partition","covariates","personalized"],"y":[65,126,50,375,129,104,207,23,31,11,991,66,33,196,142,39,288,7,26,38,230,298,90,110,4,343,29,207,615,66,3,38,121,66,219,450,803,442,136,11,148,34,40,342,2,24,130,56,422,206,50,43,68,20,420,43,161,82,31,66,2,161,8,222,52,25,35,519,14,725,258,300,113,81,15,35,147,133,558,272,19,3,51,136,22,297,33,1,60,183,113,270,37,2,284,12,21,12,93,117,98,18,139,923,91,124,39,74,123,44,4,9,52,90,182,54,41,38,12,127,31,443,67,74,7,105,104,33,92,12,389,242,64,62,128,88,248,175,117,137,19,115,10,205,139,170,14,123,69,727,7,26,23,36,156,25,21,204,81,15,3,494,2,25,174,2,33,7,39,38,2,14,55,23,3,51,1,1,11,13,3,4,9,83,273,8,24,2,60,8,135,31,81,676,4,3,86,30,5,14],"type":"bar"},{"x":["influence","improvements","potentially","important","tra ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4709,), (4709, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7447956823438705

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4851485148514852);'>Knowledge</span> <span style=''>Matters</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Importance</span> <span style=''>of</span> <span style=''>Prior</span> <span style='background-color:rgba(0, 255, 0, 0.3564189189189189);'>Information</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>We</span> <span style=''>explore</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introducing</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3564189189189189);'>information</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.52);'>intermediate</span> <span style=''>level</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>for</span> <span style=''>a</span> <span style=''>learning</span> <span style=''>task</span> <span style=''>on</span> <span style=''>which</span> <span style=''>all</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>tested</span> <span style=''>failed</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>We</span> <span style=''>motivate</span> <span style=''>our</span> <span style=''>work</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>that</span> <span style=''>humans</span> <span style=''>learn</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.52);'>intermediate</span> <span style=''>concepts</span> <span style=''>from</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.46875);'>individuals</span> <span style=''>via</span> <span style=''>a</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6883116883116883);'>supervision</span> <span style=''>or</span> <span style=''>guidance</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>curriculum</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>we</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.52);'>conducted</span> <span style=''>provide</span> <span style=''>positive</span> <span style=''>evidence</span> <span style=''>in</span> <span style=''>favor</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>In</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>a</span> <span style=''>two</span> <span style=''>tiered</span> <span style=''>MLP</span> <span style='background-color:rgba(0, 255, 0, 0.5561959654178674);'>architecture</span> <span style=''>is</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>with</span> <span style=''>64x64</span> <span style=''>binary</span> <span style=''>inputs</span> <span style=''>images</span> <span style=''>each</span> <span style=''>image</span> <span style=''>with</span> <span style=''>three</span> <span style=''>sprites</span> <span style=''>The</span> <span style=''>final</span> <span style=''>task</span> <span style=''>is</span> <span style=''>to</span> <span style=''>decide</span> <span style=''>whether</span> <span style=''>all</span> <span style=''>the</span> <span style=''>sprites</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Stability</span> <span style=''>Approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>(StARS)</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Models</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>problem</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>is</span> <span style=''>to</span> <span style=''>choose</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>in</span> <span style=''>a</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>way</span> <span style=''>The</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>include</span> <span style=''>K</span> <span style=''>fold</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <span style=''>(K</span> <span style=''>CV)</span> <span style=''>Akaike</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>(AIC)</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>(BIC)</span> <span style=''>Though</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>work</span> <span style=''>well</span> <span style=''>for</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>problems</span> <span style=''>they</span> <span style=''>are</span> <span style=''>not</span> <span style=''>suitable</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>settings</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>StARS</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>based</span> <span style=''>method</span> <span style=''>for</span> <span style=''>choosing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undirected</span> <span style=''>graphs</span> <span style=''>The</span> <span style=''>method</span> <span style=''>has</span> <span style=''>a</span> <span style=''>clear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>we</span> <span style=''>use</span> <span style=''>the</span> <span style=''>least</span> <span style=''>amount</span> <span style=''>of</span> <span style='backgroun ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sensitive</span> <span style=''>and</span> <span style=''>Robust</span> <span style=''>Decision</span> <span style=''>Making</span> <span style=''>a</span> <span style=''>CVaR</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>Approach</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>within</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>decision</span> <span style=''>process</span> <span style=''>(MDP)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>where</span> <span style=''>risk</span> <span style=''>and</span> <span style=''>modeling</span> <span style=''>errors</span> <span style=''>are</span> <span style=''>taken</span> <span style=''>into</span> <span style=''>account</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>a</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>value</span> <span style=''>at</span> <span style=''>risk</span> <span style=''>(CVaR)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>as</span> <span style=''>opposed</span> <span style=''>to</span> <span style=''>a</span> <span style=''>standard</span> <span style=''>risk</span> <span style=''>neutral</span> <span style='background-color:rgba(255, 0, 0, 0.43137254901960786);'>expectation</span> <span style=''>We</span> <span style=''>refer</span> <span style=''>to</span> <span style=''>such</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>CVaR</span> <span style=''>MDP</span> <span style=''>Our</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contribution</span> <span style=''>is</span> <span style=''>to</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>CVaR</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>besides</span> <span style='background-color:rgba(0, 255, 0, 0.34375);'>capturing</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitivity</span> <span style=''>has</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>as</span> <span style=''>expected</span> <span style=''>cost</span> <span style=''>under</span> <span style=''>worst</span> <span style=''>case</span> <span style=''>modeling</span> <span style=''>errors</span> <span style=''>for</span> <span style=''>a</span> <span style=''>given</span> <span style=''>error</span> <span style=''>budget</span> <span style=''>This</span> <span style=''>result</span> <span style=''>which</span> <span style=''>is</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>interest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivates</span> <span style=''>CVaR</span> <span style=''>MDPs</span> <span style=''>as</span> <span style=''>a</span> <span style=''>unifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style=''>and</span> <span style=''>robust</span> <span style=''>decision</span> <span style=''>ma ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Embedding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approaches</span> <span style=''>to</span> <span style=''>Orbit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Determination</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Spacecraft</span> <span style=''>Clusters</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>and</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>orbit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determination</span> <span style=''>over</span> <span style=''>finite</span> <span style=''>time</span> <span style=''>horizons</span> <span style=''>as</span> <span style=''>a</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>orbit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determination</span> <span style=''>under</span> <span style=''>very</span> <span style=''>broad</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satisfied</span> <span style=''>for</span> <span style=''>n</span> <span style=''>body</span> <span style=''>problems</span> <span style=''>These</span> <span style=''>weak</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>allow</span> <span style=''>us</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>orbit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determination</span> <span style=''>with</span> <span style=''>noisy</span> <span style=''>and</span> <span style=''>highly</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>such</span> <span style=''>as</span> <span style=''>those</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>by</span> <span style=''>range</span> <span style=''>rate</span> <span style=''>only</span> <span style=''>(Doppler</span> <span style=''>only)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>domain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>can</span> <span style=''>learn</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>orbits</span> <span style=''>of</span> <span style=''>a</span> <span style=''>group</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satellites</span> <span style=''>and</span> <span style=''>identify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satellites</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>with</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>orbits</span> <span style=''>and</span> <span style=''>provide</span> <span style='b ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13125)
# 	segmentation (0.069375)
# 	processing (0.106875)
# 	representation (0.1428125)
# 	information (0.2509375)
# 	knowledge (0.140625)
# 	detection (0.1196875)
# 	different (0.264375)
# 	recognition (0.131875)
# 	convolutional (0.1384375)
#
# Some Statistics words are:
# 	variational (0.0996477101157524)
# 	estimation (0.16607951685958733)
# 	variables (0.13789632611977856)
# 	algorithm (0.3860090588827378)
# 	theoretical (0.15702063412179165)
# 	statistical (0.16155007549068948)
# 	distribution (0.19073980875691998)
# 	dimensional (0.19778560644187218)
# 	inference (0.2073477604428787)
# 	regression (0.17916456970306996)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="710e8789-9d4b-4faf-ae88-65c749770c47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("710e8789-9d4b-4faf-ae88-65c749770c47")) {                    Plotly.newPlot(                        "710e8789-9d4b-4faf-ae88-65c749770c47",                        [{"x":["influence","improvements","potentially","important","translation","conditional","traditional","conditioned","adaptively","psychological","performance","naturally","summarization","attention","environment","vocabulary","including","contaminated","reconstructed","detectors","dimensional","technique","correlation","reconstruction","transmitted","computational","intensity","automatically","framework","represents","tokenization","integrates","retrieval","contributions","presented","knowledge","information","techniques","literature","customized","effectively","interface","scientific","processing","bibliographic","complexities","increasing","addresses","recognition","developed","applicable","syntactic","analyzing","interpreting","experimental","designing","practical","linguistic","correctly","statistics","homogeneity","stochastic","inequalities","segmentation","expressions","discrimination","criterion","applications","dissimilarity","experiments","distribution","outperforms","identification","illustrate","expressiveness","distances","comparison","distributions","classification","parameters","suggesting","statistic","capabilities","performed","asymptotic","particular","sensitivity","bhattacharyya","variation","understanding","describes","architecture","themselves","compounding","application","insufficient","interacting","utterances","predicting","generating","uncertainty","initially","underlying","algorithm","collected","combining","informative","incorporate","challenges","complicated","telephone","compensate","unlabeled","extension","selection","facilitate","collaborative","activation","inception","competitive","competition","convolutional","adaptation","dimensionality","concatenation","comparable","represented","objectives","following","formation","introduce","benchmark","convolution","difference","components","empirically","functions","efficiency","convergence","individual","possibilities","outperform","sacrificing","potential","reinforcement","combination","ensembles","mechanism","guarantees","algorithms","crowdsourced","reliability","collective","determined","unsupervised","weighting","crowdsourcing","supervised","performing","otherwise","attending","approaches","exercises","supported","challenge","nintendos","principles","progressive","platforms","experience","parkinsons","gradually","technology","motivation","amalgamation","increases","rehabilitation","dopaminergic","suitability","opportunities","repeatability","prescribed","eventually","precision","complexity","recommend","movements","predictability","character","recursively","regression","interpretable","observations","demonstrate","reformulating","personalization","achieving","partition","covariates","personalized","observational","partitioning","different","treatment","recursive","impactful","validating","evaluating","treatments","structure","aforementioned","separability","rectified","described","conditions","concretely","generalization","separately","sufficient","intuitions","assumption","resonance","development","posterior","visualizes","functional","improving","extraction","perceptron","motivating","conducted","multilayer","diagnoses","psychiatric","diagnosis","probability","generative","extractors","biological","estimates","encountered","schizophrenia","biomarkers","disorders","investigation","extracting","presenting","involving","promising","difficult","selecting","combinatorial","probabilities","efficient","dependencies"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	psychiatric
# 	schizophrenia
# 	reconcile
# 	formalise
# 	heteroscedasticity
# 	couplings
# 	trivially
# 	perceptible
# 	minimality
# 	newtonian
# 	corollary
# 	solvation
# 	quadrature
# 	sparsifying
# 	superlinear
# 	underpowered
# 	proportionally
# 	homoscedastic
# 	nonstationarity
# 	unsettled
# Some words which never appear in Statistics papers:
# 	psychological
# 	transmitted
# 	tokenization
# 	bibliographic
# 	compounding
# 	utterances
# 	telephone
# 	concatenation
# 	attending
# 	exercises
# 	nintendos
# 	amalgamation
# 	repeatability
# 	reinforced
# 	subdivision
# 	subdivided
# 	plasticity
# 	subdivisions
# 	dendrites
# 	annotating

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 2.7241275981366966e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.6908249807247494
